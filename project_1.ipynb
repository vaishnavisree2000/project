# %% [markdown]
# ***Given below are the libraries that we require to work on this dataset.***

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Load Data

# %% [markdown]
# ***Now I will load the dataset into the notebook and get an overview of the first and last few rows of the dataset.***

# %%
df=pd.read_csv('C:/Users/Acer/Downloads/Crime_Data.csv')
df
# Out:
#         division_number date_reported        date_occurred  area    area_name  \
# 0              10304468    2020-01-08  2020-01-08 22:30:00     3    Southwest
# 1             190101086    2020-01-02  2020-01-01 03:30:00     1      Central
# 2             200110444    2020-04-14  2020-02-13 12:00:00     1      Central
# 3             191501505    2020-01-01  2020-01-01 17:30:00    15  N Hollywood
# 4             191921269    2020-01-01  2020-01-01 04:15:00    19      Mission
# ...                 ...           ...                  ...   ...          ...
# 852945        231606525    2023-03-22  2023-03-22 10:00:00    16     Foothill
# 852946        231210064    2023-04-12  2023-04-12 16:30:00    12  77th Street
# 852947        230115220    2023-07-02  2023-07-01 00:01:00     1      Central
# 852948        230906458    2023-03-05  2023-03-05 09:00:00     9     Van Nuys
# 852949        230319786    2023-11-10  2023-11-09 23:00:00     3    Southwest
#
# ...

# %% [markdown]
# ***Below selecting first 10 rows***

# %%
#first 10 rows
df.head(10)
# Out:
#    division_number date_reported        date_occurred  area    area_name  \
# 0         10304468    2020-01-08  2020-01-08 22:30:00     3    Southwest
# 1        190101086    2020-01-02  2020-01-01 03:30:00     1      Central
# 2        200110444    2020-04-14  2020-02-13 12:00:00     1      Central
# 3        191501505    2020-01-01  2020-01-01 17:30:00    15  N Hollywood
# 4        191921269    2020-01-01  2020-01-01 04:15:00    19      Mission
# 5        200100501    2020-01-02  2020-01-01 00:30:00     1      Central
# 6        200100502    2020-01-02  2020-01-02 13:15:00     1      Central
# 7        200100504    2020-01-04  2020-01-04 00:40:00     1      Central
# 8        200100507    2020-01-04  2020-01-04 02:00:00     1      Central
# 9        201710201    2020-06-19  2020-05-26 19:25:00    17   Devonshire
#
#    reporting_district  part  crime_code  \
# 0                 377     2         624
# 1                 163     2         624
# ...

# %% [markdown]
# ***Below selecting last 10 rows***

# %%
#last 10 rows
df.tail(10)
# Out:
#         division_number date_reported        date_occurred  area    area_name  \
# 852940        231104474    2023-01-12  2023-01-12 12:40:00    11    Northeast
# 852941        230804266    2023-01-08  2023-01-08 10:30:00     8      West LA
# 852942        231510379    2023-05-29  2023-05-25 11:00:00    15  N Hollywood
# 852943        231110961    2023-07-09  2023-07-06 12:00:00    11    Northeast
# 852944        231604807    2023-01-27  2023-01-26 18:00:00    16     Foothill
# 852945        231606525    2023-03-22  2023-03-22 10:00:00    16     Foothill
# 852946        231210064    2023-04-12  2023-04-12 16:30:00    12  77th Street
# 852947        230115220    2023-07-02  2023-07-01 00:01:00     1      Central
# 852948        230906458    2023-03-05  2023-03-05 09:00:00     9     Van Nuys
# 852949        230319786    2023-11-10  2023-11-09 23:00:00     3    Southwest
#
#         reporting_district  part  crime_code  \
# 852940                1107     1         440
# ...

# %% [markdown]
# ## 3. BASIC INFORMATION ##

# %% [markdown]
# ***Just to get the basic information regarding the dataset.***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852950 entries, 0 to 852949
# Data columns (total 27 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   division_number      852950 non-null  int64
#  1   date_reported        852950 non-null  object
#  2   date_occurred        852950 non-null  object
#  3   area                 852950 non-null  int64
#  4   area_name            852950 non-null  object
#  5   reporting_district   852950 non-null  int64
#  6   part                 852950 non-null  int64
#  7   crime_code           852950 non-null  int64
#  8   crime_description    852950 non-null  object
#  9   modus_operandi       734639 non-null  object
#  10  victim_age           852950 non-null  int64
#  11  victim_sex           740344 non-null  object
#  12  victim_descent       740336 non-null  object
#  13  premise_code         852940 non-null  float64
#  14  premise_description  852432 non-null  object
# ...

# %% [markdown]
# ## 4. Checking Datatype

# %% [markdown]
# ***To determine the type of each column for graph plotting.***

# %%
df.dtypes
# Out:
# division_number          int64
# date_reported           object
# date_occurred           object
# area                     int64
# area_name               object
# reporting_district       int64
# part                     int64
# crime_code               int64
# crime_description       object
# modus_operandi          object
# victim_age               int64
# victim_sex              object
# victim_descent          object
# premise_code           float64
# premise_description     object
# weapon_code            float64
# weapon_description      object
# status                  object
# status_description      object
# crime_code_1           float64
# crime_code_2           float64
# crime_code_3           float64
# crime_code_4           float64
# location                object
# cross_street            object
# latitude               float64
# longitude              float64
# dtype: object

# %% [markdown]
# ***All the necessary columns required for graph plotting are in numerical format therfore conversion won't be required.***

# %% [markdown]
# ## 5. Drop Unnecessary Columns

# %% [markdown]
# ***I will not be needing all the  columns in this dataset for my EDA. Hence dropping off all irrelevant columns.***

# %%
df=df.drop(columns=['part','crime_code_3','crime_code_4','victim_descent'])
df
# Out:
#         division_number date_reported        date_occurred  area    area_name  \
# 0              10304468    2020-01-08  2020-01-08 22:30:00     3    Southwest
# 1             190101086    2020-01-02  2020-01-01 03:30:00     1      Central
# 2             200110444    2020-04-14  2020-02-13 12:00:00     1      Central
# 3             191501505    2020-01-01  2020-01-01 17:30:00    15  N Hollywood
# 4             191921269    2020-01-01  2020-01-01 04:15:00    19      Mission
# ...                 ...           ...                  ...   ...          ...
# 852945        231606525    2023-03-22  2023-03-22 10:00:00    16     Foothill
# 852946        231210064    2023-04-12  2023-04-12 16:30:00    12  77th Street
# 852947        230115220    2023-07-02  2023-07-01 00:01:00     1      Central
# 852948        230906458    2023-03-05  2023-03-05 09:00:00     9     Van Nuys
# 852949        230319786    2023-11-10  2023-11-09 23:00:00     3    Southwest
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852950 entries, 0 to 852949
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   division_number      852950 non-null  int64
#  1   date_reported        852950 non-null  object
#  2   date_occurred        852950 non-null  object
#  3   area                 852950 non-null  int64
#  4   area_name            852950 non-null  object
#  5   reporting_district   852950 non-null  int64
#  6   crime_code           852950 non-null  int64
#  7   crime_description    852950 non-null  object
#  8   modus_operandi       734639 non-null  object
#  9   victim_age           852950 non-null  int64
#  10  victim_sex           740344 non-null  object
#  11  premise_code         852940 non-null  float64
#  12  premise_description  852432 non-null  object
#  13  weapon_code          296748 non-null  float64
#  14  weapon_description   296748 non-null  object
# ...

# %% [markdown]
# ## 6. Rename columns

# %% [markdown]
# ***Renaming columns for better understanding.***

# %% [markdown]
# ***we changed modus operandi to MO(Modus Operandi)***
#
# ***what is modus operandi ?***
#
#  ***A Latin phrase meaning “mode of operating”, is an identifying characteristic or behavioral pattern that we use to identify somebody through the way they commit a crime.***

# %%
df=df.rename(columns={'modus_operandi':'M O(modus operandi)'})
df
# Out:
#         division_number date_reported        date_occurred  area    area_name  \
# 0              10304468    2020-01-08  2020-01-08 22:30:00     3    Southwest
# 1             190101086    2020-01-02  2020-01-01 03:30:00     1      Central
# 2             200110444    2020-04-14  2020-02-13 12:00:00     1      Central
# 3             191501505    2020-01-01  2020-01-01 17:30:00    15  N Hollywood
# 4             191921269    2020-01-01  2020-01-01 04:15:00    19      Mission
# ...                 ...           ...                  ...   ...          ...
# 852945        231606525    2023-03-22  2023-03-22 10:00:00    16     Foothill
# 852946        231210064    2023-04-12  2023-04-12 16:30:00    12  77th Street
# 852947        230115220    2023-07-02  2023-07-01 00:01:00     1      Central
# 852948        230906458    2023-03-05  2023-03-05 09:00:00     9     Van Nuys
# 852949        230319786    2023-11-10  2023-11-09 23:00:00     3    Southwest
#
# ...

# %% [markdown]
# ***Below We capitalized the all headings first letter***

# %%
for i in df:
    j=i.replace (' ','_')
    df.rename(columns={i:j.capitalize()},inplace=True)
df
# Out:
#         Division_number Date_reported        Date_occurred  Area    Area_name  \
# 0              10304468    2020-01-08  2020-01-08 22:30:00     3    Southwest
# 1             190101086    2020-01-02  2020-01-01 03:30:00     1      Central
# 2             200110444    2020-04-14  2020-02-13 12:00:00     1      Central
# 3             191501505    2020-01-01  2020-01-01 17:30:00    15  N Hollywood
# 4             191921269    2020-01-01  2020-01-01 04:15:00    19      Mission
# ...                 ...           ...                  ...   ...          ...
# 852945        231606525    2023-03-22  2023-03-22 10:00:00    16     Foothill
# 852946        231210064    2023-04-12  2023-04-12 16:30:00    12  77th Street
# 852947        230115220    2023-07-02  2023-07-01 00:01:00     1      Central
# 852948        230906458    2023-03-05  2023-03-05 09:00:00     9     Van Nuys
# 852949        230319786    2023-11-10  2023-11-09 23:00:00     3    Southwest
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852950 entries, 0 to 852949
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Division_number      852950 non-null  int64
#  1   Date_reported        852950 non-null  object
#  2   Date_occurred        852950 non-null  object
#  3   Area                 852950 non-null  int64
#  4   Area_name            852950 non-null  object
#  5   Reporting_district   852950 non-null  int64
#  6   Crime_code           852950 non-null  int64
#  7   Crime_description    852950 non-null  object
#  8   M_o(modus_operandi)  734639 non-null  object
#  9   Victim_age           852950 non-null  int64
#  10  Victim_sex           740344 non-null  object
#  11  Premise_code         852940 non-null  float64
#  12  Premise_description  852432 non-null  object
#  13  Weapon_code          296748 non-null  float64
#  14  Weapon_description   296748 non-null  object
# ...

# %% [markdown]
# ## 7. Searching & Dropping Duplicate Rows

# %% [markdown]
# ***Find any duplicate row and delete them if found.***

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 852945    False
# 852946    False
# 852947    False
# 852948    False
# 852949    False
# Length: 852950, dtype: bool

# %% [markdown]
# ## 8. Drop Missing or Null Values
#
# ***The idea of this step is to drop any missing values that are found in the data. So first let's check for any missing value.***

# %%
df.isnull().sum()
# Out:
# Division_number             0
# Date_reported               0
# Date_occurred               0
# Area                        0
# Area_name                   0
# Reporting_district          0
# Crime_code                  0
# Crime_description           0
# M_o(modus_operandi)    118311
# Victim_age                  0
# Victim_sex             112606
# Premise_code               10
# Premise_description       518
# Weapon_code            556202
# Weapon_description     556202
# Status                      0
# Status_description          0
# Crime_code_1               11
# Crime_code_2           790429
# Location                    0
# Cross_street           717289
# Latitude                    0
# Longitude                   0
# dtype: int64

# %% [markdown]
# ***In the above output, columns such as method of working,victim_sex ,premise_code ,premise_description,etc can have null values but other colums such as division_number,date_reported,etc can't have those null values. Hence the Next step involves finding the crimes details whose stat values are null.***

# %%
arr = df['M_o(modus_operandi)'].isnull()
arr
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 852945    False
# 852946    False
# 852947    False
# 852948    False
# 852949    False
# Name: M_o(modus_operandi), Length: 852950, dtype: bool

# %%
data = np.where(arr)
data
# Out:
# (array([    33,     45,     78, ..., 852916, 852926, 852928], dtype=int64),)

# %%
df.iloc[data]
# Out:
#         Division_number Date_reported        Date_occurred  Area   Area_name  \
# 33            200117988    2020-09-15  2020-09-03 20:00:00     1     Central
# 45            221412410    2022-06-15  2020-11-12 17:00:00    14     Pacific
# 78            200104073    2020-01-02  2020-01-02 03:45:00     1     Central
# 104           200516527    2020-11-12  2020-11-12 04:30:00     5      Harbor
# 105           200609101    2020-04-15  2020-04-12 13:00:00     6   Hollywood
# ...                 ...           ...                  ...   ...         ...
# 852891        230307052    2023-02-28  2023-02-27 19:00:00     3   Southwest
# 852900        230713941    2023-08-30  2023-08-30 02:45:00     7    Wilshire
# 852916        231309462    2023-04-20  2023-04-20 09:00:00    13      Newton
# 852926        230406516    2023-03-19  2023-03-19 01:22:00     4  Hollenbeck
# 852928        230609209    2023-05-01  2023-04-29 06:00:00     6   Hollywood
#
#         Reporting_district  Crime_code  \
# ...

# %% [markdown]
# ***The Above table shows the details of crimes that needs to be dropped due to the presence of null values. The Last step of this process involves dropping those rows.***

# %%
df.dropna(subset=['M_o(modus_operandi)'],inplace=True)
df
# Out:
#         Division_number Date_reported        Date_occurred  Area    Area_name  \
# 0              10304468    2020-01-08  2020-01-08 22:30:00     3    Southwest
# 1             190101086    2020-01-02  2020-01-01 03:30:00     1      Central
# 2             200110444    2020-04-14  2020-02-13 12:00:00     1      Central
# 3             191501505    2020-01-01  2020-01-01 17:30:00    15  N Hollywood
# 4             191921269    2020-01-01  2020-01-01 04:15:00    19      Mission
# ...                 ...           ...                  ...   ...          ...
# 852945        231606525    2023-03-22  2023-03-22 10:00:00    16     Foothill
# 852946        231210064    2023-04-12  2023-04-12 16:30:00    12  77th Street
# 852947        230115220    2023-07-02  2023-07-01 00:01:00     1      Central
# 852948        230906458    2023-03-05  2023-03-05 09:00:00     9     Van Nuys
# 852949        230319786    2023-11-10  2023-11-09 23:00:00     3    Southwest
#
# ...

# %%
df.isnull().sum()
# Out:
# Division_number             0
# Date_reported               0
# Date_occurred               0
# Area                        0
# Area_name                   0
# Reporting_district          0
# Crime_code                  0
# Crime_description           0
# M_o(modus_operandi)         0
# Victim_age                  0
# Victim_sex                461
# Premise_code                0
# Premise_description       506
# Weapon_code            438489
# Weapon_description     438489
# Status                      0
# Status_description          0
# Crime_code_1               11
# Crime_code_2           672321
# Location                    0
# Cross_street           620598
# Latitude                    0
# Longitude                   0
# dtype: int64

# %%
arr1=df['Weapon_description'].isnull()
arr1
# Out:
# 0         False
# 1         False
# 2          True
# 3          True
# 4          True
#           ...
# 852945    False
# 852946    False
# 852947     True
# 852948     True
# 852949     True
# Name: Weapon_description, Length: 734639, dtype: bool

# %%
data1=np.where(arr1)
data1
# Out:
# (array([     2,      3,      4, ..., 734636, 734637, 734638], dtype=int64),)

# %%
df.iloc[data1]
# Out:
#         Division_number Date_reported        Date_occurred  Area    Area_name  \
# 2             200110444    2020-04-14  2020-02-13 12:00:00     1      Central
# 3             191501505    2020-01-01  2020-01-01 17:30:00    15  N Hollywood
# 4             191921269    2020-01-01  2020-01-01 04:15:00    19      Mission
# 6             200100502    2020-01-02  2020-01-02 13:15:00     1      Central
# 7             200100504    2020-01-04  2020-01-04 00:40:00     1      Central
# ...                 ...           ...                  ...   ...          ...
# 852943        231110961    2023-07-09  2023-07-06 12:00:00    11    Northeast
# 852944        231604807    2023-01-27  2023-01-26 18:00:00    16     Foothill
# 852947        230115220    2023-07-02  2023-07-01 00:01:00     1      Central
# 852948        230906458    2023-03-05  2023-03-05 09:00:00     9     Van Nuys
# 852949        230319786    2023-11-10  2023-11-09 23:00:00     3    Southwest
#
# ...

# %%
df.dropna(subset=['Weapon_description'], inplace=True)

# %%
df.isnull().sum()
# Out:
# Division_number             0
# Date_reported               0
# Date_occurred               0
# Area                        0
# Area_name                   0
# Reporting_district          0
# Crime_code                  0
# Crime_description           0
# M_o(modus_operandi)         0
# Victim_age                  0
# Victim_sex                128
# Premise_code                0
# Premise_description       188
# Weapon_code                 0
# Weapon_description          0
# Status                      0
# Status_description          0
# Crime_code_1                3
# Crime_code_2           255743
# Location                    0
# Cross_street           226824
# Latitude                    0
# Longitude                   0
# dtype: int64

# %% [markdown]
# ## ***pair plots are useful for exploring relationships between multiple variables in a dataset***
#
# ***A pairplot plot a pairwise relationships in a dataset. The pairplot function creates a grid of Axes such that each variable in data will by shared in the y-axis across a single row and in the x-axis across a single column. That creates plots as shown below.***

# %%
df2=df.head(15)
sns.pairplot(df2)
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## 9. Exploring Data based on Certain Criteria

# %% [markdown]
# ## Now we go deep into the analysis of our data. The analysis involves sorting and grouping of crime stats based certain questions that are mentioned below.

# %% [markdown]
# ***which area has the highest crime rate?***

# %% [markdown]
# ***This Data provides information on crimes that occur in each area.The following is the details of the crimes committed in each area.***

# %%
Ac=df[['Area_name']]                           
Ac
# Out:
#           Area_name
# 0         Southwest
# 1           Central
# 5           Central
# 10          Central
# 11          Central
# ...             ...
# 852930  N Hollywood
# 852935    Hollywood
# 852938     Van Nuys
# 852945     Foothill
# 852946  77th Street
#
# [296150 rows x 1 columns]

# %%
Axc = pd.DataFrame(Ac)
gr = Axc.groupby(Axc.columns.tolist()).size().reset_index(name='count')

re = gr[gr['count'] > 1]

print("Re:")
print(re['count'])
# Out:
# Re:
# 0     26139
# 1     22816
# 2      9409
# 3      9449
# 4     12127
# 5     11498
# 6     18025
# 7     11196
# 8     11508
# 9     17832
# 10     9907
# 11    15650
# 12    13705
# 13    16752
# 14    20795
# 15    18264
# 16     9794
# 17    10031
# 18     9324
# 19    10978
# 20    10951
# Name: count, dtype: int64

# %%
print(re['count'].max())
gro = Axc.groupby(Axc.columns.tolist()).size()
gro.idxmax()
# Out:
# 26139
# '77th Street'

# %%
s=df['Area_name'].value_counts()
sorted_area_counts=s.sort_values(ascending=False)
top_areas=sorted_area_counts.head(5)
print(top_areas)
sns.countplot(x="Area_name",data=df,order=top_areas.index)
plt.title('Top 5 Area Names')
plt.xlabel('Area_name')
plt.ylabel('count')
plt.xticks(rotation=45)
plt.show()
# Out:
# 77th Street    26139
# Central        22816
# Southeast      20795
# Southwest      18264
# Hollywood      18025
# Name: Area_name, dtype: int64

# %% [markdown]
# ***In the basis of above information that we  realised which area has the highest crime rate from among the top 5 areas, "77th Street" is highest crime area.There are lot of areas in the crime data we sort out them and take top 5 of them and find which area is on the top"77th street" is the part of central city.Central city is the highest crime rated area in los Angeles. Overall, the high crime rate in the central city's 77th Street area is likely influenced by a combination of socioeconomic, historical, law enforcement, and community-related factors. Addressing these underlying issues through comprehensive strategies that focus on community development, crime prevention, and social equity can help reduce crime rates and improve the overall well-being of residents in the area***

# %%
df[(df['Area_name']=='77th Street')]
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 df[(df['Area_name']=='77th Street')]
# ----> 2 x
#
# NameError: name 'x' is not defined

# %% [markdown]
# ***which area has the lowest crime rate?***

# %%
Alc = pd.DataFrame(Ac)
gr = Alc.groupby(Alc.columns.tolist()).size().reset_index(name='count')

re = gr[gr['count'] > 1]

print("Re:")
print(re['count'])
# Out:
# Re:
# 0     26139
# 1     22816
# 2      9409
# 3      9449
# 4     12127
# 5     11498
# 6     18025
# 7     11196
# 8     11508
# 9     17832
# 10     9907
# 11    15650
# 12    13705
# 13    16752
# 14    20795
# 15    18264
# 16     9794
# 17    10031
# 18     9324
# 19    10978
# 20    10951
# Name: count, dtype: int64

# %%
print(re['count'].max())
gro = Alc.groupby(Alc.columns.tolist()).size()
gro.idxmin()
# Out:
# 26139
# 'West LA'

# %% [markdown]
# ***In the basis of above information that we realised which area has the lowest crime rate from among the top 5 areas, "West LA" is lowest crime area.There are lot of areas in the crime data we sort out them and take top 5 of them and find which area is on the 5th position.Overall, the combination of affluence, residential stability, effective policing, access to resources, and community engagement contributes to West Los Angeles being perceived as one of the lowest crime-rated areas in Los Angeles. However, it's essential to recognize that crime can still occur in any neighborhood, and ongoing efforts to maintain public safety and community well-being are necessary.***

# %% [markdown]
# ***what are the most used weapons by criminals?***

# %% [markdown]
# ***Below the information is about most used weapons by criminals***

# %%
x=df['Weapon_description'].duplicated()
x
# Out:
# 0         False
# 1         False
# 5          True
# 10        False
# 11        False
#           ...
# 852930     True
# 852935     True
# 852938     True
# 852945     True
# 852946     True
# Name: Weapon_description, Length: 296150, dtype: bool

# %%
x=df['Weapon_description'].head(20)
x
# Out:
# 0     STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 1                        UNKNOWN WEAPON/OTHER WEAPON
# 5                        UNKNOWN WEAPON/OTHER WEAPON
# 10                                ROCK/THROWN OBJECT
# 11                                     VERBAL THREAT
# 13                       UNKNOWN WEAPON/OTHER WEAPON
# 15    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 16    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 17    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 19                                     FOLDING KNIFE
# 24                       UNKNOWN WEAPON/OTHER WEAPON
# 27                       UNKNOWN WEAPON/OTHER WEAPON
# 28    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 29    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 32    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 34                       UNKNOWN WEAPON/OTHER WEAPON
# 37    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 39    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# ...

# %%
df3 = pd.DataFrame(x)
grouped_counts = df3.groupby(df3.columns.tolist()).size().reset_index(name='count')

repeated_objects = grouped_counts[grouped_counts['count'] > 1]

print("Repeated objects:")
print(repeated_objects['count'])
# Out:
# Repeated objects:
# 4    9
# 5    6
# Name: count, dtype: int64

# %%
print(repeated_objects['count'].max())
# Out:
# 9

# %%
grouped_counts = df3.groupby(df3.columns.tolist()).size()
grouped_counts.idxmax()
# Out:
# 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)'

# %%
grouped_counts.idxmin()
# Out:
# 'BLUNT INSTRUMENT'

# %%
weapons_data=df3
colours=sns.color_palette('pastel')[0:len(weapons_data)]
plt.pie(x=weapons_data.value_counts(),labels=weapons_data.value_counts().index,autopct="%1.1f%%", colors=colours,startangle=90)
plt.title("MOST USED WEAPONS BY CRIMINALS")
plt.show()

# %% [markdown]
# ***In the above informations we find out that 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)' is the most used weapon by criminals and 'BLUNT INSTRUMENT'is most less used weapon, we shows it graphically to understand others easily.The choice of weapon used by criminals depends on various factors, including accessibility, discretion, intimidation value, legal consequences, and practicality in the context of the crime being committed.***

# %% [markdown]
# ***Which year is the highest number of crime reported ?***

# %%
CBY = df.groupby('Date_reported').size().reset_index(name='Crime_Count')
CBY
# Out:
#      Date_reported  Crime_Count
# 0       2020-01-01          236
# 1       2020-01-02          190
# 2       2020-01-03          156
# 3       2020-01-04          182
# 4       2020-01-05          180
# ...            ...          ...
# 1429    2023-11-30          170
# 1430    2023-12-01          178
# 1431    2023-12-02          186
# 1432    2023-12-03          165
# 1433    2023-12-04          105
#
# [1434 rows x 2 columns]

# %%
MCY= CBY.loc[CBY['Crime_Count'].idxmax()]
MCY
# Out:
# Date_reported    2023-07-31
# Crime_Count             294
# Name: 1307, dtype: object

# %% [markdown]
# ***In the above information shows that "2023-07-31" date is highest number of crime reported***
#
#
# ***In 2023, Los Angeles experienced a notable increase in reported criminal activity on various dates throughout the year. Among these incidents, one date stood out as having the highest number of reported crimes. On "2023-07-31" , law enforcement agencies in Los Angeles responded to a surge in criminal incidents, including " BATTERY - SIMPLE ASSAULT, RAPE, FORCIBLE, BURGLARY FROM VEHICLE, etc" which significantly exceeded the average daily rate. This spike in criminal activity prompted increased patrols, investigations, and community outreach efforts to address public safety concerns and prevent further incidents. The exact reasons for the peak in crime on this date may vary and could be influenced by factors such as socioeconomic conditions, gang activity, or specific events occurring in the city.***

# %% [markdown]
# ***which age groups are most often victims of a crime?***

# %%
x22=df[['Crime_description','Victim_age']]
x22
# Out:
#                                      Crime_description  Victim_age
# 0                             BATTERY - SIMPLE ASSAULT          36
# 1                             BATTERY - SIMPLE ASSAULT          25
# 5                                       RAPE, FORCIBLE          25
# 10                               BURGLARY FROM VEHICLE          29
# 11              CRIMINAL THREATS - NO WEAPON DISPLAYED          35
# ...                                                ...         ...
# 852930                                 BRANDISH WEAPON          38
# 852935                                         ROBBERY          23
# 852938                        BATTERY - SIMPLE ASSAULT          44
# 852945  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT          25
# 852946  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT          29
#
# [296150 rows x 2 columns]

# %% [markdown]
# ***The above data indicates which AGE group commits more crimes.***
# ***For that purpose, 20-30, 30-40, 40-50 will be divided into age groups.***

# %%
# ag=df.sort_values(by='Victim_age')
xa=x22[(x22['Victim_age']>20) & (x22['Victim_age']<31)]
xa[1:]
xa.count()
# Out:
# Crime_description    73143
# Victim_age           73143
# dtype: int64

# %% [markdown]
# ***Above is the list of people between 20 - 30 years of age. The number of crimes committed in this age group is 73143.***

# %%
x1=x22[(x22['Victim_age']>30) & (x22['Victim_age']<41)]
x1.count()
# Out:
# Crime_description    65859
# Victim_age           65859
# dtype: int64

# %% [markdown]
# ***Above is the list of people between 30 - 40 years of age. The number of crimes committed in this age group is 65859.***

# %%
x2=x22[(x22['Victim_age']>40) & (x22['Victim_age']<51)]
x2.count()
# Out:
# Crime_description    44667
# Victim_age           44667
# dtype: int64

# %% [markdown]
# ***Above is the list of people between 40 - 50 years of age. The number of crimes committed in this age group is 73143.***
# ***finally understand the age between 20-30 commit the most crime***

# %% [markdown]
# ## Teenagers are the ones who commit the most crime. Because in our society, it is this age group that gets lost with drugs and alcohol. That's why this age group is involved in the most crimes.

# %% [markdown]
# ***Which genter has committed the most crimes?***

# %%
a1=df[('Victim_sex')]
a1
# Out:
# 0         F
# 1         M
# 5         F
# 10        M
# 11        M
#          ..
# 852930    M
# 852935    F
# 852938    M
# 852945    F
# 852946    M
# Name: Victim_sex, Length: 296150, dtype: object

# %%
a2 = pd.DataFrame(a1)
grouped_counts = a2.groupby(a2.columns.tolist()).size().reset_index(name='count')

repeated_objects = grouped_counts[grouped_counts['count'] > 1]

print("Repeated objects:")
print(repeated_objects['count'])
print(repeated_objects['count'].max())
# Out:
# Repeated objects:
# 0    135450
# 1        26
# 2    143467
# 3     17079
# Name: count, dtype: int64
# 143467

# %%
grouped_counts = a2.groupby(a2.columns.tolist()).size()
grouped_counts.idxmax()
# Out:
# 'M'

# %%
sns.countplot(x=df['Victim_sex'],data=df)
plt.show()

# %% [markdown]
# ## We find out that "Males" are  most crimes committed in between 2020-2023

# %% [markdown]
# ***In which location crime the highest?***

# %%
Hcl=df[['Location']]
Hcl
# Out:
#                                         Location
# 0        1100 W  39TH                         PL
# 1         700 S  HILL                         ST
# 5                                700 S  BROADWAY
# 10                                          15TH
# 11        800 N  ALAMEDA                      ST
# ...                                          ...
# 852930  11000    MCCORMICK                    ST
# 852935   5500    HOLLYWOOD                    BL
# 852938   6200    SYLMAR                       AV
# 852945  12800    FILMORE                      ST
# 852946   6100 S  VERMONT                      AV
#
# [296150 rows x 1 columns]

# %%
Axc = pd.DataFrame(Hcl)
gr = Hcl.groupby(Hcl.columns.tolist()).size().reset_index(name='count').head(20)

re = gr[gr['count'] > 1]

print("Re:")
print(re['count'])
# Out:
# Re:
# 0     4
# 1     6
# 2     2
# 3     2
# 5     3
# 6     3
# 7     3
# 8     3
# 10    4
# 12    4
# 13    7
# 15    3
# 17    5
# Name: count, dtype: int64

# %%
print(re['count'].max())
gr = Hcl.groupby(Hcl.columns.tolist()).size()
gr.idxmax()
# Out:
# 7
# '6TH'

# %%
gr.idxmin()
# Out:
# '00    23RD                         AV'

# %%
plt.figure(figsize=(6, 6))
plt.pie(re['count'], labels=re['Location'], autopct='%1.1f%%')
plt.title('Pie Chart of Location Counts')
plt.show()

# %% [markdown]
# ## In the above graph & informations shows that '6TH' is  the highest crime occured location

# %% [markdown]
# ## WHAT are the reason 6th streat highest crime occured location.
#
# ***1.Socioeconomic Factors: Areas with high poverty rates often experience higher crime rates. If 6th Street or its surrounding neighborhoods face economic challenges such as unemployment, lack of affordable housing, or limited access to education and resources, this could contribute to higher crime rates.***
#
# ***2.Gang Activity: Gangs sometimes operate in certain areas, leading to increased violence and criminal activity. If 6th Street is known for gang presence or if rival gangs clash in the area, it could lead to a higher incidence of crimes like shootings and drug trafficking.***
#
# ***3.Drug Trafficking: Drug-related crimes, including drug trafficking and drug-related violence, can occur in areas where drug activity is prevalent. If 6th Street is a hub for drug trafficking or drug use, it could lead to associated crimes.***
#
# ***4.Lack of Policing or Community Programs: Inadequate policing or a lack of community programs aimed at crime prevention and intervention can allow criminal activity to flourish. If there are not enough law enforcement resources allocated to 6th Street or if community programs that address root causes of crime are lacking, it could contribute to increased criminal behavior.***
#
# ***5.Social Disorganization: Areas with high population turnover, social disorganization, or a lack of community cohesion may be more susceptible to crime. If residents feel disconnected from their community or if there is a breakdown in social networks, it could create an environment where criminal activity goes unchecked.***

# %% [markdown]
# ## ' 23RD is the lowest crime rated location

# %% [markdown]
# ***What type of crime is committed the most?***

# %%
CCM=df[['Crime_description','Crime_code']].head(20)
CCM
# Out:
#                                  Crime_description  Crime_code
# 0                         BATTERY - SIMPLE ASSAULT         624
# 1                         BATTERY - SIMPLE ASSAULT         624
# 5                                   RAPE, FORCIBLE         121
# 10                           BURGLARY FROM VEHICLE         330
# 11          CRIMINAL THREATS - NO WEAPON DISPLAYED         930
# 13                                           ARSON         648
# 15               INTIMATE PARTNER - SIMPLE ASSAULT         626
# 16               INTIMATE PARTNER - SIMPLE ASSAULT         626
# 17              THEFT PLAIN - PETTY ($950 & UNDER)         440
# 19                                         ROBBERY         210
# 24  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT         230
# 27  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT         230
# 28                        BATTERY - SIMPLE ASSAULT         624
# 29                                  RAPE, FORCIBLE         121
# ...

# %%
tc = pd.DataFrame(CCM)
g = CCM.groupby(CCM.columns.tolist()).size().reset_index(name='count')

r= g[g['count'] > 1]

print("R:")
print(r['count'])
print(r['count'].max())
# Out:
# R:
# 1    4
# 2    5
# 4    2
# 5    3
# 6    2
# Name: count, dtype: int64
# 5

# %%
print(r['count'].max())
gr = CCM.groupby(CCM.columns.tolist()).size()
gr.idxmax()
# Out:
# 5
# ('BATTERY - SIMPLE ASSAULT', 624)

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,5))
sns.lineplot(x='Crime_description', y='Crime_code',data=CCM, marker='o', markersize=8)
plt.xticks(rotation=45,ha='right')

plt.xlabel('Crime_description')
plt.ylabel('Crime_code')
plt.title('Crime Committed The Most')
plt.show()

# %% [markdown]
# ***In the above graph & informations shows that 'BATTERY - SIMPLE ASSAULT',624 is the type of crime committed the most .The prevalence of "BATTERY - SIMPLE ASSAULT" as the most commonly committed type of crime in Los Angeles reflects the complex interplay of social, economic, and legal factors influencing interpersonal violence in urban environments. Addressing underlying issues such as substance abuse, mental health, and socioeconomic disparities is crucial in reducing the incidence of simple assault and promoting community safety.***

# %% [markdown]
# ***How many cases are currently going on?***

# %%
Cgo=df[['Status_description']]
Cgo
# Out:
#        Status_description
# 0             Adult Other
# 1             Invest Cont
# 5             Invest Cont
# 10            Invest Cont
# 11            Invest Cont
# ...                   ...
# 852930        Adult Other
# 852935        Invest Cont
# 852938        Invest Cont
# 852945        Invest Cont
# 852946        Invest Cont
#
# [296150 rows x 1 columns]

# %%
Cgo = pd.DataFrame(Cgo)
gr = Cgo.groupby(Cgo.columns.tolist()).size().reset_index(name='count')

re = gr[gr['count'] > 1]

print("Re:")
print(re['count'])
# Out:
# Re:
# 0     47483
# 1     66142
# 2    179330
# 3      2109
# 4      1084
# 5         2
# Name: count, dtype: int64

# %%
print(re['count'].max())
gr = Cgo.groupby(Cgo.columns.tolist()).size()
gr.idxmax()
# Out:
# 179330
# 'Invest Cont'

# %%
sns.countplot(df,x="Status_description",hue='Status')
# Out:
# <Axes: xlabel='Status_description', ylabel='count'>

# %% [markdown]
# ***In the above graph & informations shows that 'Invest Cont' is cases are currently going on .Referring to ongoing investigations or legal proceedings related to crimes in Los Angeles Complexity,Legal Procedures,Resource Allocation,Defense Strategies,Court Backlog ,These factors commonly contribute to the length of legal proceedings in criminal cases. ***

# %% [markdown]
# ***How many robbery's reported in 2020-2023 (graphically representation)?***

# %%
df4=df.sample(100000)
RR=df4[(df4['Crime_description']=='ROBBERY')]
RR
# Out:
#         Division_number Date_reported        Date_occurred  Area    Area_name  \
# 144176        202113577    2020-09-07  2020-09-07 21:25:00    21      Topanga
# 843313        232000872    2023-08-03  2023-08-03 16:28:00    20      Olympic
# 822721        230115873    2023-07-12  2023-07-12 12:13:00     1      Central
# 769941        232006257    2023-02-23  2023-02-23 16:00:00    20      Olympic
# 803438        231809132    2023-04-17  2023-04-17 20:15:00    18    Southeast
# ...                 ...           ...                  ...   ...          ...
# 510228        221908429    2022-04-19  2022-04-18 20:00:00    19      Mission
# 33095         200507768    2020-03-31  2020-03-31 04:50:00     5       Harbor
# 118702        201908386    2020-04-03  2020-04-03 19:45:00    19      Mission
# 638521        221223920    2022-11-21  2022-11-20 11:00:00    12  77th Street
# 426631        220206704    2022-03-04  2022-03-04 13:45:00     2      Rampart
#
# ...

# %% [markdown]
# ***How many juvenile crimes are there,and what are the most common crime they commit ?***

# %%
Jc=df[(df['Victim_age']>0)&(df['Victim_age']<18)]
# Jc=df[(df['Victim_age']<18)].head(20)
Jc
# Out:
#         Division_number Date_reported        Date_occurred  Area   Area_name  \
# 109           211304982    2021-01-23  2020-07-24 01:00:00    13      Newton
# 179           200405489    2020-02-07  2020-02-06 21:15:00     4  Hollenbeck
# 200           210916323    2021-11-09  2020-11-09 08:00:00     9    Van Nuys
# 204           200104408    2020-01-06  2020-01-06 22:00:00     1     Central
# 220           201822182    2020-12-15  2020-12-09 21:00:00    18   Southeast
# ...                 ...           ...                  ...   ...         ...
# 852775        231405988    2023-02-17  2023-02-17 15:40:00    14     Pacific
# 852802        231908557    2023-04-27  2023-04-26 09:15:00    19     Mission
# 852835        230311153    2023-05-20  2023-05-20 18:20:00     3   Southwest
# 852866        230609390    2023-05-05  2023-05-05 13:00:00     6   Hollywood
# 852924        231608412    2023-05-21  2023-05-20 21:30:00    16    Foothill
#
#         Reporting_district  Crime_code  \
# ...

# %%
sns.countplot(x=Jc['Victim_age'], data=Jc,color='orange', edgecolor='red')
plt.show()

# %% [markdown]
# ***Some of the common factors contributing to juvenile delinquency in Los Angeles specifically Socioeconomic Challenges,Gang Involvement,Substance Abuse,Family Dysfunction,Educational Disparities,Cultural and Social Influences.Addressing juvenile delinquency in Los Angeles requires a comprehensive approach that includes community-based interventions, access to education and employment opportunities, mental health and substance abuse treatment, and efforts to address underlying social and economic disparities. By addressing these root causes, communities can work towards reducing juvenile crime and promoting the well-being of young people.***

# %% [markdown]
# ## CONCLUSION
#
# ***Here we looked at the data of various types of crimes committed in Los Angeles for the years 2020-2023. From this data, we can understand that people between the age group of 20 to 30 years commit the most crimes. Sixth Street is the most crime-ridden area,23rd is the lowest lowest crime , with the highest number of crimes committed ('Battery - Simple Assault', 624).Analyzing the data of each year, it is seen that the number of crimes is increasing every year. The only ways to prevent this is to provide awareness, provide proper education, police and law to give the maximum punishment to those who commit crimes. All these will help to reduce the number of crimes.In los angeles many juvenile crimes are also there, by addressing the root causes, communities can work towards reducing juvenile crime and promoting the well-being of young people***
